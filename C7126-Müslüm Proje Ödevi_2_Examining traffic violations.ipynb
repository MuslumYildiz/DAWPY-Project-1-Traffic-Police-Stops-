# %% [markdown]
# # Examining traffic violations

# %%
import pandas as pd

# %%
# Count the unique values in the violation column, to see what violations are being committed by all drivers.

# %%
ri = pd.read_csv('police.csv')

# %%
ri.head()
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# 0             False              NaN         NaN            False
# 1             False              NaN         NaN            False
# 2             False              NaN         NaN            False
# 3             False              NaN         NaN            False
# 4             False              NaN         NaN            False
#
#   stop_outcome is_arrested stop_duration out_of_state drugs_related_stop  \
# 0     Citation       False      0-15 Min        False              False
# 1     Citation       False     16-30 Min        False              False
# 2          NaN         NaN           NaN          NaN              False
# 3     Citation       False      0-15 Min        False              False
# 4     Citation       False      0-15 Min        False              False
#
#    district
# 0   Zone K1
# 1   Zone X4
# 2   Zone X1
# 3   Zone X4
# 4   Zone X4
#
# [5 rows x 26 columns]

# %%
# Count the unique values in the violation column, to see what violations are being committed by all drivers.

# %%
print(ri.violation.value_counts())
# Out:
# Speeding               268744
# Moving violation        90234
# Equipment               61252
# Other                   24221
# Registration/plates     19830
# Seat belt               16327
# Name: violation, dtype: int64

# %%
# Express the violation counts as proportions of the total.

# %%
print(ri.violation.value_counts(normalize=True))
# Out:
# Speeding               0.559175
# Moving violation       0.187750
# Equipment              0.127447
# Other                  0.050397
# Registration/plates    0.041260
# Seat belt              0.033972
# Name: violation, dtype: float64

# %% [markdown]
# # Comparing violations by gender

# %%
# Create a DataFrame, female, that only contains rows in which driver_gender is 'F'.

# %%
female = ri[ri.driver_gender == 'F']

# %%
female
# Out:
#                    id state   stop_date stop_time location_raw  county_name  \
# 15      RI-2005-00016    RI  2005-02-24     01:20      Zone X3          NaN
# 18      RI-2005-00019    RI  2005-03-14     10:00      Zone K3          NaN
# 25      RI-2005-00026    RI  2005-03-29     23:20      Zone K3          NaN
# 34      RI-2005-00035    RI  2005-06-06     13:20      Zone X4          NaN
# 36      RI-2005-00037    RI  2005-06-18     16:30      Zone X4          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509656  RI-2015-47051    RI  2015-12-31     21:59      Zone K3          NaN
# 509659  RI-2015-47054    RI  2015-12-31     22:09      Zone K3          NaN
# 509660  RI-2015-47055    RI  2015-12-31     22:10      Zone X4          NaN
# 509661  RI-2015-47056    RI  2015-12-31     22:10      Zone X4          NaN
# 509665  RI-2015-47060    RI  2015-12-31     22:39      Zone K3          NaN
#
#         county_fips  fine_grained_location police_department driver_gender  \
# 15              NaN                    NaN               200             F
# 18              NaN                    NaN               300             F
# 25              NaN                    NaN               300             F
# 34              NaN                    NaN               500             F
# 36              NaN                    NaN               500             F
# ...             ...                    ...               ...           ...
# 509656          NaN                    NaN               300             F
# 509659          NaN                    NaN               300             F
# 509660          NaN                    NaN               300             F
# 509661          NaN                    NaN               300             F
# 509665          NaN                    NaN               300             F
#
#         ...  search_conducted  search_type_raw search_type contraband_found  \
# 15      ...             False              NaN         NaN            False
# 18      ...             False              NaN         NaN            False
# 25      ...             False              NaN         NaN            False
# 34      ...             False              NaN         NaN            False
# 36      ...             False              NaN         NaN            False
# ...     ...               ...              ...         ...              ...
# 509656  ...             False              NaN         NaN            False
# 509659  ...             False              NaN         NaN            False
# 509660  ...             False              NaN         NaN            False
# 509661  ...             False              NaN         NaN            False
# 509665  ...             False              NaN         NaN            False
#
#          stop_outcome is_arrested stop_duration out_of_state  \
# 15           Citation       False      0-15 Min         True
# 18           Citation       False      0-15 Min        False
# 25           Citation       False      0-15 Min         True
# 34           Citation       False      0-15 Min        False
# 36      Arrest Driver        True       30+ Min        False
# ...               ...         ...           ...          ...
# 509656       Citation       False      0-15 Min        False
# 509659        Warning       False      0-15 Min        False
# 509660        Warning       False      0-15 Min        False
# 509661  Arrest Driver        True      0-15 Min        False
# 509665       Citation       False     16-30 Min         True
#
#        drugs_related_stop  district
# 15                  False   Zone X3
# 18                  False   Zone K3
# 25                  False   Zone K3
# 34                  False   Zone X4
# 36                  False   Zone X4
# ...                   ...       ...
# 509656              False   Zone K3
# 509659              False   Zone K3
# 509660              False   Zone X4
# 509661              False   Zone X4
# 509665              False   Zone K3
#
# [131138 rows x 26 columns]

# %%
# Create a DataFrame, male, that only contains rows in which driver_gender is 'M'.

# %%
male = ri[ri.driver_gender == 'M']

# %%
male
# Out:
#                    id state   stop_date stop_time location_raw  county_name  \
# 0       RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 3       RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# 5       RI-2005-00006    RI  2005-01-12     08:05      Zone X1          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509666  RI-2015-47061    RI  2015-12-31     22:46      Zone X1          NaN
# 509667  RI-2015-47062    RI  2015-12-31     22:47      Zone X4          NaN
# 509668  RI-2015-47063    RI  2015-12-31     23:08      Zone X3          NaN
# 509669  RI-2015-47064    RI  2015-12-31     23:44      Zone K2          NaN
# 509670  RI-2015-47065    RI  2015-12-31     23:48      Zone K3          NaN
#
#         county_fips  fine_grained_location police_department driver_gender  \
# 0               NaN                    NaN               600             M
# 1               NaN                    NaN               500             M
# 3               NaN                    NaN               500             M
# 4               NaN                    NaN               500             M
# 5               NaN                    NaN                 0             M
# ...             ...                    ...               ...           ...
# 509666          NaN                    NaN                 0             M
# 509667          NaN                    NaN               500             M
# 509668          NaN                    NaN               200             M
# 509669          NaN                    NaN               900             M
# 509670          NaN                    NaN               300             M
#
#         ...  search_conducted  search_type_raw search_type contraband_found  \
# 0       ...             False              NaN         NaN            False
# 1       ...             False              NaN         NaN            False
# 3       ...             False              NaN         NaN            False
# 4       ...             False              NaN         NaN            False
# 5       ...             False              NaN         NaN            False
# ...     ...               ...              ...         ...              ...
# 509666  ...             False              NaN         NaN            False
# 509667  ...             False              NaN         NaN            False
# 509668  ...             False              NaN         NaN            False
# 509669  ...             False              NaN         NaN            False
# 509670  ...             False              NaN         NaN            False
#
#        stop_outcome is_arrested stop_duration out_of_state drugs_related_stop  \
# 0          Citation       False      0-15 Min        False              False
# 1          Citation       False     16-30 Min        False              False
# 3          Citation       False      0-15 Min        False              False
# 4          Citation       False      0-15 Min        False              False
# 5          Citation       False       30+ Min         True              False
# ...             ...         ...           ...          ...                ...
# 509666     Citation       False      0-15 Min         True              False
# 509667     Citation       False      0-15 Min        False              False
# 509668     Citation       False      0-15 Min        False              False
# 509669     Citation       False      0-15 Min        False              False
# 509670     Citation       False      0-15 Min        False              False
#
#         district
# 0        Zone K1
# 1        Zone X4
# 3        Zone X4
# 4        Zone X4
# 5        Zone X1
# ...          ...
# 509666   Zone X1
# 509667   Zone X4
# 509668   Zone X3
# 509669   Zone K2
# 509670   Zone K3
#
# [349446 rows x 26 columns]

# %%
# Count the violations committed by female drivers and express them as proportions.

# %%
print(female.violation.value_counts(normalize=True))
# Out:
# Speeding               0.657308
# Moving violation       0.136581
# Equipment              0.107055
# Registration/plates    0.043077
# Other                  0.028908
# Seat belt              0.027071
# Name: violation, dtype: float64

# %%
# Count the violations committed by male drivers and express them as proportions.

# %%
print(male.violation.value_counts(normalize=True))
# Out:
# Speeding               0.522364
# Moving violation       0.206948
# Equipment              0.135102
# Other                  0.058450
# Registration/plates    0.040581
# Seat belt              0.036555
# Name: violation, dtype: float64

# %%
# Comparing speeding outcomes by gender

# %%
# Create a DataFrame, female_and_speeding, that only includes female drivers who were stopped for speeding.

# %%
female_and_speeding = ri[(ri.driver_gender == 'F') & (ri.violation  == 'Speeding')]

# %%
female_and_speeding
# Out:
#                    id state   stop_date stop_time location_raw  county_name  \
# 15      RI-2005-00016    RI  2005-02-24     01:20      Zone X3          NaN
# 18      RI-2005-00019    RI  2005-03-14     10:00      Zone K3          NaN
# 25      RI-2005-00026    RI  2005-03-29     23:20      Zone K3          NaN
# 34      RI-2005-00035    RI  2005-06-06     13:20      Zone X4          NaN
# 37      RI-2005-00038    RI  2005-07-06     11:22      Zone X1          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509633  RI-2015-47028    RI  2015-12-31     19:44      Zone K2          NaN
# 509636  RI-2015-47031    RI  2015-12-31     20:05      Zone K2          NaN
# 509646  RI-2015-47041    RI  2015-12-31     20:42      Zone K2          NaN
# 509655  RI-2015-47050    RI  2015-12-31     21:47      Zone K3          NaN
# 509656  RI-2015-47051    RI  2015-12-31     21:59      Zone K3          NaN
#
#         county_fips  fine_grained_location police_department driver_gender  \
# 15              NaN                    NaN               200             F
# 18              NaN                    NaN               300             F
# 25              NaN                    NaN               300             F
# 34              NaN                    NaN               500             F
# 37              NaN                    NaN                 0             F
# ...             ...                    ...               ...           ...
# 509633          NaN                    NaN               500             F
# 509636          NaN                    NaN               900             F
# 509646          NaN                    NaN               900             F
# 509655          NaN                    NaN               300             F
# 509656          NaN                    NaN               300             F
#
#         ...  search_conducted  search_type_raw search_type contraband_found  \
# 15      ...             False              NaN         NaN            False
# 18      ...             False              NaN         NaN            False
# 25      ...             False              NaN         NaN            False
# 34      ...             False              NaN         NaN            False
# 37      ...             False              NaN         NaN            False
# ...     ...               ...              ...         ...              ...
# 509633  ...             False              NaN         NaN            False
# 509636  ...             False              NaN         NaN            False
# 509646  ...             False              NaN         NaN            False
# 509655  ...             False              NaN         NaN            False
# 509656  ...             False              NaN         NaN            False
#
#        stop_outcome is_arrested stop_duration out_of_state drugs_related_stop  \
# 15         Citation       False      0-15 Min         True              False
# 18         Citation       False      0-15 Min        False              False
# 25         Citation       False      0-15 Min         True              False
# 34         Citation       False      0-15 Min        False              False
# 37         Citation       False      0-15 Min        False              False
# ...             ...         ...           ...          ...                ...
# 509633      Warning       False      0-15 Min        False              False
# 509636     Citation       False      0-15 Min        False              False
# 509646     Citation       False      0-15 Min         True              False
# 509655     Citation       False      0-15 Min         True              False
# 509656     Citation       False      0-15 Min        False              False
#
#         district
# 15       Zone X3
# 18       Zone K3
# 25       Zone K3
# 34       Zone X4
# 37       Zone X1
# ...          ...
# 509633   Zone K2
# 509636   Zone K2
# 509646   Zone K2
# 509655   Zone K3
# 509656   Zone K3
#
# [86198 rows x 26 columns]

# %%
# Create a DataFrame, male_and_speeding, that only includes male drivers who were stopped for speeding.

# %%
male_and_speeding = ri[(ri.driver_gender == 'M') & (ri.violation  == 'Speeding')]

# %%
male_and_speeding
# Out:
#                    id state   stop_date stop_time location_raw  county_name  \
# 0       RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 6       RI-2005-00007    RI  2005-01-18     08:15      Zone K3          NaN
# 8       RI-2005-00009    RI  2005-01-23     23:15      Zone K3          NaN
# 9       RI-2005-00010    RI  2005-01-24     20:32      Zone K1          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509649  RI-2015-47044    RI  2015-12-31     20:50      Zone K2          NaN
# 509654  RI-2015-47049    RI  2015-12-31     21:42      Zone X1          NaN
# 509663  RI-2015-47058    RI  2015-12-31     22:26      Zone K3          NaN
# 509666  RI-2015-47061    RI  2015-12-31     22:46      Zone X1          NaN
# 509669  RI-2015-47064    RI  2015-12-31     23:44      Zone K2          NaN
#
#         county_fips  fine_grained_location police_department driver_gender  \
# 0               NaN                    NaN               600             M
# 1               NaN                    NaN               500             M
# 6               NaN                    NaN               300             M
# 8               NaN                    NaN               300             M
# 9               NaN                    NaN               600             M
# ...             ...                    ...               ...           ...
# 509649          NaN                    NaN               500             M
# 509654          NaN                    NaN                 0             M
# 509663          NaN                    NaN               300             M
# 509666          NaN                    NaN                 0             M
# 509669          NaN                    NaN               900             M
#
#         ...  search_conducted  search_type_raw     search_type  \
# 0       ...             False              NaN             NaN
# 1       ...             False              NaN             NaN
# 6       ...             False              NaN             NaN
# 8       ...             False              NaN             NaN
# 9       ...              True   Probable Cause  Probable Cause
# ...     ...               ...              ...             ...
# 509649  ...             False              NaN             NaN
# 509654  ...             False              NaN             NaN
# 509663  ...             False              NaN             NaN
# 509666  ...             False              NaN             NaN
# 509669  ...             False              NaN             NaN
#
#        contraband_found stop_outcome is_arrested stop_duration out_of_state  \
# 0                 False     Citation       False      0-15 Min        False
# 1                 False     Citation       False     16-30 Min        False
# 6                 False     Citation       False      0-15 Min         True
# 8                 False     Citation       False      0-15 Min         True
# 9                  True     Citation       False      0-15 Min         True
# ...                 ...          ...         ...           ...          ...
# 509649            False     Citation       False      0-15 Min        False
# 509654            False     Citation       False      0-15 Min         True
# 509663            False     Citation       False      0-15 Min         True
# 509666            False     Citation       False      0-15 Min         True
# 509669            False     Citation       False      0-15 Min        False
#
#        drugs_related_stop  district
# 0                   False   Zone K1
# 1                   False   Zone X4
# 6                   False   Zone K3
# 8                   False   Zone K3
# 9                    True   Zone K1
# ...                   ...       ...
# 509649              False   Zone K2
# 509654              False   Zone X1
# 509663              False   Zone K3
# 509666              False   Zone X1
# 509669              False   Zone K2
#
# [182538 rows x 26 columns]

# %%
# Count the stop outcomes for the female drivers and express them as proportions.

# %%
print(female_and_speeding.stop_outcome.value_counts(normalize=True))
# Out:
# Citation            0.953247
# Warning             0.039003
# Arrest Driver       0.005290
# Arrest Passenger    0.001033
# N/D                 0.000905
# No Action           0.000522
# Name: stop_outcome, dtype: float64

# %%
# Count the stop outcomes for the male drivers and express them as proportions.

# %%
print(male_and_speeding.stop_outcome.value_counts(normalize=True))
# Out:
# Citation            0.944636
# Warning             0.036086
# Arrest Driver       0.015767
# Arrest Passenger    0.001265
# N/D                 0.001183
# No Action           0.001063
# Name: stop_outcome, dtype: float64

# %% [markdown]
# # Calculating the search rate

# %%
# Check the data type of search_conducted to confirm that it's a Boolean Series.
# Calculate the search rate by counting the Series values and expressing them as proportions.
# Calculate the search rate by taking the mean of the Series. (It should match the proportion of True values calculated above.)

# %%
print(ri.search_conducted.dtype)
# Out:
# object

# %%
print(ri.search_conducted.value_counts(normalize=True))
# Out:
# False    0.96515
# True     0.03485
# Name: search_conducted, dtype: float64

# %%
print(ri.search_conducted.mean())
# Out:
# 0.034849932603581525

# %% [markdown]
# # Comparing search rates by gender

# %%
# Filter the DataFrame to only include female drivers, 
# and then calculate the search rate by taking the mean of search_conducted.

# %%
print(ri[ri.driver_gender=='F'].search_conducted.mean())
# Out:
# 0.018751239152648355

# %% [markdown]
# # Filter the DataFrame to only include male drivers, and then repeat the search rate calculation.

# %%
print(ri[ri.driver_gender=='M'].search_conducted.mean())
# Out:
# 0.04379217389811301

# %% [markdown]
# # Group by driver gender to calculate the search rate for both groups simultaneously. (It should match the previous results.)

# %% [markdown]
# # Adding a second factor to the analysis

# %%
# Use a .groupby() to calculate the search rate for each combination of gender and violation. 
# Are males and females searched at about the same rate for each violation?

# %% [markdown]
# # Reverse the ordering to group by violation before gender. The results may be easier to compare when presented this way.

# %%
print(ri.groupby(['violation', 'driver_gender']).search_conducted.mean())
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-93-471bc32f3b4d> in <module>
# ----> 1 print(ri.groupby(['violation', 'driver_gender']).search_conducted.mean())
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1391         Name: B, dtype: float64
#    1392         """
# -> 1393         return self._cython_agg_general(
#    1394             "mean",
#    1395             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1049
#    1050         if len(output) == 0:
# -> 1051             raise DataError("No numeric types to aggregate")
#    1052
#    1053         return self._wrap_aggregated_output(output, index=self.grouper.result_index)
#
# DataError: No numeric types to aggregate

# %% [markdown]
# # Counting protective frisks

# %%
# Count the search_type values to see how many times "Protective Frisk" was the only search type.
# Create a new column, frisk, that is True if search_type contains the string "Protective Frisk" and False otherwise.
# Check the data type of frisk to confirm that it's a Boolean Series.
# Take the sum of frisk to count the total number of frisks.

# %%
print(ri.search_type.value_counts())
# Out:
# Incident to Arrest                                          6998
# Probable Cause                                              4989
# Reasonable Suspicion                                        1141
# Inventory                                                   1101
# Protective Frisk                                             879
# Incident to Arrest,Inventory                                 649
# Incident to Arrest,Probable Cause                            552
# Probable Cause,Reasonable Suspicion                          334
# Probable Cause,Protective Frisk                              221
# Incident to Arrest,Protective Frisk                          158
# Incident to Arrest,Inventory,Probable Cause                  151
# Inventory,Probable Cause                                     132
# Protective Frisk,Reasonable Suspicion                         83
# Incident to Arrest,Inventory,Protective Frisk                 77
# Incident to Arrest,Probable Cause,Protective Frisk            74
# Inventory,Protective Frisk                                    52
# Incident to Arrest,Reasonable Suspicion                       49
# Probable Cause,Protective Frisk,Reasonable Suspicion          31
# Incident to Arrest,Probable Cause,Reasonable Suspicion        31
# Inventory,Reasonable Suspicion                                17
# Inventory,Probable Cause,Protective Frisk                     14
# Incident to Arrest,Inventory,Reasonable Suspicion             12
# Inventory,Probable Cause,Reasonable Suspicion                  8
# Incident to Arrest,Protective Frisk,Reasonable Suspicion       8
# Inventory,Protective Frisk,Reasonable Suspicion                1
# Name: search_type, dtype: int64

# %%
ri['frisk'] = ri.search_type.str.contains('Protective Frisk', na=False)

# %%
ri['frisk']
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 509676    False
# 509677    False
# 509678    False
# 509679    False
# 509680    False
# Name: frisk, Length: 509681, dtype: bool

# %%
print(ri.frisk.dtype)
# Out:
# bool

# %%
print(ri.frisk.sum())
# Out:
# 1598

# %% [markdown]
# # Comparing frisk rates by gender

# %%
# Create a DataFrame, searched, that only contains rows in which search_conducted is True.

# %%
searched = ri[ri.search_conducted==True]

# %%
searched
# Out:
#                    id state   stop_date stop_time location_raw  county_name  \
# 9       RI-2005-00010    RI  2005-01-24     20:32      Zone K1          NaN
# 10      RI-2005-00011    RI  2005-02-09     03:05      Zone X4          NaN
# 83      RI-2005-00084    RI  2005-08-28     01:00      Zone X1          NaN
# 93      RI-2005-00094    RI  2005-09-15     02:20      Zone X4          NaN
# 114     RI-2005-00115    RI  2005-09-24     02:20      Zone K3          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509311  RI-2015-46706    RI  2015-12-28     11:05      Zone K3          NaN
# 509475  RI-2015-46870    RI  2015-12-30     01:37      Zone X4          NaN
# 509508  RI-2015-46903    RI  2015-12-30     08:51      Zone K3          NaN
# 509539  RI-2015-46934    RI  2015-12-30     13:15      Zone X3          NaN
# 509555  RI-2015-46950    RI  2015-12-30     15:58      Zone K2          NaN
#
#         county_fips  fine_grained_location police_department driver_gender  \
# 9               NaN                    NaN               600             M
# 10              NaN                    NaN               500             M
# 83              NaN                    NaN                 0             M
# 93              NaN                    NaN               500             M
# 114             NaN                    NaN               300             M
# ...             ...                    ...               ...           ...
# 509311          NaN                    NaN               300             F
# 509475          NaN                    NaN               500             M
# 509508          NaN                    NaN               300             F
# 509539          NaN                    NaN               200             M
# 509555          NaN                    NaN               900             M
#
#         ...                                    search_type_raw  \
# 9       ...                                     Probable Cause
# 10      ...                         Probable Cause,Terry Frisk
# 83      ...                     Incident to Arrest,Terry Frisk
# 93      ...                                 Incident to Arrest
# 114     ...                                 Incident to Arrest
# ...     ...                                                ...
# 509311  ...                                 Incident to Arrest
# 509475  ...                                        Terry Frisk
# 509508  ...                Probable Cause,Reasonable Suspicion
# 509539  ...                                 Incident to Arrest
# 509555  ...  Odor of Drugs/Alcohol,Probable Cause,Reasonabl...
#
#                                 search_type contraband_found  \
# 9                            Probable Cause             True
# 10          Probable Cause,Protective Frisk            False
# 83      Incident to Arrest,Protective Frisk            False
# 93                       Incident to Arrest            False
# 114                      Incident to Arrest            False
# ...                                     ...              ...
# 509311                   Incident to Arrest             True
# 509475                     Protective Frisk            False
# 509508  Probable Cause,Reasonable Suspicion             True
# 509539                   Incident to Arrest            False
# 509555  Probable Cause,Reasonable Suspicion            False
#
#             stop_outcome is_arrested stop_duration out_of_state  \
# 9               Citation       False      0-15 Min         True
# 10              Citation       False      0-15 Min        False
# 83         Arrest Driver        True     16-30 Min         True
# 93         Arrest Driver        True     16-30 Min        False
# 114        Arrest Driver        True     16-30 Min        False
# ...                  ...         ...           ...          ...
# 509311          Citation       False     16-30 Min         True
# 509475          Citation       False      0-15 Min        False
# 509508          Citation       False       30+ Min         True
# 509539  Arrest Passenger        True     16-30 Min         True
# 509555          Citation       False       30+ Min         True
#
#        drugs_related_stop district  frisk
# 9                    True  Zone K1  False
# 10                  False  Zone X4   True
# 83                  False  Zone X1   True
# 93                  False  Zone X4  False
# 114                 False  Zone K3  False
# ...                   ...      ...    ...
# 509311               True  Zone K3  False
# 509475              False  Zone X4   True
# 509508               True  Zone K3  False
# 509539              False  Zone X3  False
# 509555              False  Zone K2  False
#
# [17762 rows x 27 columns]

# %%
# Take the mean of the frisk column to find out what percentage of searches included a frisk.

# %%
print(searched.frisk.mean())
# Out:
# 0.08996734601959239

# %%
# Calculate the frisk rate for each gender using a .groupby().

# %%
print(searched.groupby('driver_gender').frisk.mean())
# Out:
# driver_gender
# F    0.066694
# M    0.093707
# Name: frisk, dtype: float64
